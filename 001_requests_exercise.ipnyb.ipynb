# %%
# %pip install anthropic python-dotenv

# %%
from anthropic import Anthropic

client = Anthropic()

messages = []
model = "claude-sonnet-4-6"


def add_user_message(messages: list, text: str):
    user_message = {
        "role": "user",
        "content": text
    }
    messages.append(user_message)

def add_assistant_message(messages: list, text: str):
    assistant_message = {
        "role": "assistant",
        "content": text
    }
    messages.append(assistant_message)

def chat(messages: list):
    message = client.messages.create(
        model=model,
        max_tokens=1024,
        messages=messages
    )
    return message.content[0].text

while True:
    user_input = input(">")

    print(">", user_input)
    if user_input == "exit":
        break

    add_user_message(messages, user_input)
    answer = chat(messages)
    add_assistant_message(messages, answer)
    print("---\n", answer, "\n---")
# Out:
# > What is the capital city of India?
# ---
#  The capital city of India is **New Delhi**. It serves as the seat of the Indian government and is located in the National Capital Territory (NCT) of Delhi.
# ---
#
# > How big is it?
# ---
#  New Delhi and the broader Delhi region is quite large:
#
# - **National Capital Territory (NCT) of Delhi** covers an area of about **1,484 square kilometers (573 square miles)**
# - The **population** of Delhi NCT is approximately **33 million people** (as of recent estimates), making it one of the most populous urban areas in the world
# - **New Delhi** itself, as a specific district within Delhi, is much smaller, covering about **42.7 square kilometers (16.5 square miles)**
#
# Delhi is generally considered the **second largest city in India** by population, after Mumbai, and is among the **largest cities in the world** by population. It is a sprawling metropolitan area with a dense and rapidly growing population.
# ---
#
# > exit
