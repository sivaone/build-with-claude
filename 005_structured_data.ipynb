# %%
from dotenv import load_dotenv
from anthropic import Anthropic
load_dotenv()

client = Anthropic()
model = "claude-sonnet-4-6"

def add_user_message(messages, text):
    user_message = {
        "role": "user",
        "content": text
    }
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {
        "role": "assistant",
        "content": text
    }
    messages.append(assistant_message)

def chat(messages, stop_sequences=None, system_message=None):
    params = {
        "model": model,
        "messages": messages,
        "max_tokens": 1024,
    }
    if system_message:
        params["system"] = system_message

    if stop_sequences:
        params["stop_sequences"]=stop_sequences

    message = client.messages.create(**params)
    return message.content[0].text

# %%
messages = []
# add_user_message(messages, "Generate just a sample Azure policy json for storing files in blob storage without comments or explanation.")
# Below prefill is not supported in latest claude models. It will give error.
# Error: This model does not support assistant message prefill. The conversation must end with a user message.
# add_assistant_message(messages, "```json")
# response = chat(messages, stop_sequences=["```"])
# print(response)

# %%
add_user_message(messages, "Generate a sample Azure policy json for storing files in blob storage.")
response = chat(messages, system_message="Respond with raw JSON only without markdown. No explanation.")
print(response)
# Out:
# ```json
# {
#   "properties": {
#     "displayName": "Enforce Azure Blob Storage Security Policy",
#     "description": "This policy enforces security and compliance settings for Azure Blob Storage accounts including HTTPS, encryption, public access, and minimum TLS version.",
#     "mode": "All",
#     "metadata": {
#       "version": "1.0.0",
#       "category": "Storage"
#     },
#     "parameters": {
#       "effect": {
#         "type": "String",
#         "metadata": {
#           "displayName": "Effect",
#           "description": "Enable or disable the execution of the policy"
#         },
#         "allowedValues": [
#           "Audit",
#           "Deny",
#           "Disabled"
#         ],
#         "defaultValue": "Audit"
#       },
#       "minimumTlsVersion": {
#         "type": "String",
#         "metadata": {
#           "displayName": "Minimum TLS Version",
#           "description": "Minimum TLS version required for blob storage"
#         },
# ...
